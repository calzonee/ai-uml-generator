# %% [markdown]
# # Kosten Nutzen - LLM Vergleich
# Eine Kosten-Nutzen Rechnung verschiedener LLM-Lösungen, auf dessen Grundlage Technologien und LLMs ausgewählt werden sollen.

# %%
import matplotlib.pyplot as plt

# Sample data (later imported via pandas)
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

# Create a line plot
plt.plot(x, y, marker='o')

# Add titles and labels
plt.title('Simple Line Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

# Show the plot
plt.show()

# %% [markdown]
# Das Diagramm ist nur ein Platzhalter.
# https://medium.com/@Experto_AI/llm-apis-price-comparison-by-model-66d1c7bd259d
# Die Daten werden über eine API eingeholt. Mit Pandas werden gezielt Daten ausgewählter LLMs verarbeitet.
